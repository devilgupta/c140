# %% [markdown]
# <a href="https://colab.research.google.com/github/devilgupta/c140/blob/main/c138_(MOVIE_RECOMMENDATION).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-70b702fb-1f76-4a3c-a44b-9b182b6a0e8f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-70b702fb-1f76-4a3c-a44b-9b182b6a0e8f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d tmdb/tmdb-movie-metadata
# Out:
# ...
# 100% 8.89M/8.89M [00:00<00:00, 92.3MB/s]

# %%
# !ls
# Out:
# kaggle.json  sample_data  tmdb-movie-metadata.zip

# %%
# !unzip tmdb-movie-metadata.zip
# Out:
# Archive:  tmdb-movie-metadata.zip
#   inflating: tmdb_5000_credits.csv
#   inflating: tmdb_5000_movies.csv

# %%
import pandas as pd
import csv

df1=pd.read_csv("tmdb_5000_credits.csv")
df2=pd.read_csv("tmdb_5000_movies.csv")

df1.head()
# Out:
#    movie_id  ...                                               crew
# 0     19995  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1       285  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2    206647  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     49026  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     49529  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 4 columns]

# %%
df2.head(10)
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
# 5  258000000  ...       3576
# 6  260000000  ...       3330
# 7  280000000  ...       6767
# 8  250000000  ...       5293
# 9  250000000  ...       7004
#
# [10 rows x 20 columns]

# %%
df1.columns=["id","title","cast","crew"]
df2=df2.merge(df1,on="id")
df2.head(6)
# Out:
#       budget  ...                                               crew
# 0  237000000  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  300000000  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  245000000  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  250000000  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  260000000  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# 5  258000000  ...  [{"credit_id": "52fe4252c3a36847f80151a5", "de...
#
# [6 rows x 23 columns]

# %%
#c139
C= df2["vote_average"].mean()
print(C)
# Out:
# 6.092171559442011

# %%
m=df2["vote_count"].quantile(0.9)
print(m)
# Out:
# 1838.4000000000015

# %%
q_movies=df2.copy().loc[df2["vote_count"]>=m]
print(q_movies.shape)
# Out:
# (481, 23)

# %%
def weighted_rating(x,m=m,C=C):
  v=x["vote_count"]
  R=x["vote_average"]
  return (v / (v + m))*R + (m / (v + m))*C
q_movies["score"]=q_movies.apply(weighted_rating,axis=1)
q_movies=q_movies.sort_values("score", ascending=False)
q_movies[["original_title","vote_count","vote_average","score"]].head(10)
# Out:
#                                      original_title  ...     score
# 1881                       The Shawshank Redemption  ...  8.059258
# 662                                      Fight Club  ...  7.939256
# 65                                  The Dark Knight  ...  7.920020
# 3232                                   Pulp Fiction  ...  7.904645
# 96                                        Inception  ...  7.863239
# 3337                                  The Godfather  ...  7.851236
# 95                                     Interstellar  ...  7.809479
# 809                                    Forrest Gump  ...  7.803188
# 329   The Lord of the Rings: The Return of the King  ...  7.727243
# 1990                        The Empire Strikes Back  ...  7.697884
#
# [10 rows x 4 columns]

# %%
import plotly.express as px

fig=px.bar((q_movies.head(10).sort_values("score",ascending=False)),x="original_title",y="score",orientation="v")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="16ef270b-a4c2-444e-960d-e692cb0c9906" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("16ef270b-a4c2-444e-960d-e692cb0c9906")) {
#                     Plotly.newPlot(
#                         '16ef270b-a4c2-444e-960d-e692cb0c9906',
# ...

# %%
#c140
df2[["original_title","cast","crew","keywords","genres"]].head(10)
# Out:
#                              original_title  ...                                             genres
# 0                                    Avatar  ...  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  Pirates of the Caribbean: At World's End  ...  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2                                   Spectre  ...  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3                     The Dark Knight Rises  ...  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4                               John Carter  ...  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5                              Spider-Man 3  ...  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6                                   Tangled  ...  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7                   Avengers: Age of Ultron  ...  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...

# %%
from ast import literal_eval
features=["cast","crew","keywords","genres"]
for feature in features:
  df2[feature]=df2[feature].apply(literal_eval)
df2.dtypes
# Out:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title_x                  object
# vote_average            float64
# vote_count                int64
# title_y                  object
# cast                     object
# crew                     object
# dtype: object

# %%
import numpy as np
def get_director(x):
  for i in x:
    if i["job"]==("Director"):
      return i["name"]
  return np.nan
df2["director"]=df2["crew"].apply(get_director)
df2.head()
# Out:
#       budget  ...           director
# 0  237000000  ...      James Cameron
# 1  300000000  ...     Gore Verbinski
# 2  245000000  ...         Sam Mendes
# 3  250000000  ...  Christopher Nolan
# 4  260000000  ...     Andrew Stanton
#
# [5 rows x 24 columns]

# %%
def get_list(x):
  if isinstance(x,list):
    names=[i["name"]for i in x]
    return names
  return []
features=["cast","keywords","genres"]
for feature in features:
  df2[feature]=df2[feature].apply(get_list)
df2.head()
# Out:
#       budget  ...           director
# 0  237000000  ...      James Cameron
# 1  300000000  ...     Gore Verbinski
# 2  245000000  ...         Sam Mendes
# 3  250000000  ...  Christopher Nolan
# 4  260000000  ...     Andrew Stanton
#
# [5 rows x 24 columns]

# %%
df2[["original_title","cast","director","keywords","genres"]].head(10)
# Out:
#                              original_title  ...                                         genres
# 0                                    Avatar  ...  [Action, Adventure, Fantasy, Science Fiction]
# 1  Pirates of the Caribbean: At World's End  ...                   [Adventure, Fantasy, Action]
# 2                                   Spectre  ...                     [Action, Adventure, Crime]
# 3                     The Dark Knight Rises  ...               [Action, Crime, Drama, Thriller]
# 4                               John Carter  ...           [Action, Adventure, Science Fiction]
# 5                              Spider-Man 3  ...                   [Fantasy, Action, Adventure]
# 6                                   Tangled  ...                            [Animation, Family]
# 7                   Avengers: Age of Ultron  ...           [Action, Adventure, Science Fiction]
# 8    Harry Potter and the Half-Blood Prince  ...                   [Adventure, Fantasy, Family]
# ...

# %%
def clean_data(x):
  if isinstance(x,list):
    return [str.lower(i.replace(" ",""))for i in x]
  else:
    if isinstance(x,str):
      return str.lower(x.replace(" ",""))
    else:
      return ""
features=["cast","keywords","genres","director"]
for feature in features:
  df2[feature]=df2[feature].apply(clean_data)
df2.head()
# Out:
#       budget  ...          director
# 0  237000000  ...      jamescameron
# 1  300000000  ...     goreverbinski
# 2  245000000  ...         sammendes
# 3  250000000  ...  christophernolan
# 4  260000000  ...     andrewstanton
#
# [5 rows x 24 columns]

# %%
a=["Hello","How","Are","You"]
" ".join(a)
# Out:
# 'Hello How Are You'

# %%
def create_soup(x):
  return " ".join(x["keywords"])+" ".join(x["cast"])+" ".join(x["director"])+" ".join(x["genres"])
df2["soup"]=df2.apply(create_soup,axis=1)
df2.head()
# Out:
#       budget  ...                                               soup
# 0  237000000  ...  cultureclash future spacewar spacecolony socie...
# 1  300000000  ...  ocean drugabuse exoticisland eastindiatradingc...
# 2  245000000  ...  spy basedonnovel secretagent sequel mi6 britis...
# 3  250000000  ...  dccomics crimefighter terrorist secretidentity...
# 4  260000000  ...  basedonnovel mars medallion spacetravel prince...
#
# [5 rows x 25 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
count=CountVectorizer(stop_words="english")
count_matrix=count.fit_transform(df2["soup"])
from sklearn.metrics.pairwise import cosine_similarity
cosine_sin2=cosine_similarity(count_matrix,count_matrix)
df2=df2.reset_index()
indices=pd.Series(df2.index,index=df2["original_title"])

# %%
def get_recommendations(title,cosine_sin):
  idx=indices[title]
  sin_scores=list(enumerate(cosine_sin[idx]))
  sin_scores=sorted(sin_scores,key=lambda x:x[1],reverse=True)
  sin_scores=sin_scores[1:11]
  movie_indices=[i[0]for i in sin_scores]
  return df2["original_title"].iloc[movie_indices]

# %%
get_recommendations("Fight Club",cosine_sin2)
# Out:
# 946             The Game
# 1553               Se7en
# 2492               Steel
# 421               Zodiac
# 3119          Free Style
# 4236            Mooz-lum
# 1057        Coach Carter
# 838               Alien³
# 2608    Black Snake Moan
# 3649       Lovely, Still
# Name: original_title, dtype: object

# %%
get_recommendations("Harry Potter and the Half-Blood Prince",cosine_sin2)
# Out:
# 113     Harry Potter and the Order of the Phoenix
# 191      Harry Potter and the Prisoner of Azkaban
# 114           Harry Potter and the Goblet of Fire
# 276       Harry Potter and the Chamber of Secrets
# 197      Harry Potter and the Philosopher's Stone
# 3670                              Running Forever
# 1686                                The Borrowers
# 1984                    The Thief and the Cobbler
# 234                                    The Croods
# 1734                                A Simple Wish
# Name: original_title, dtype: object
